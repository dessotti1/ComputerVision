# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('cafe.jpg', 0)

# %% [markdown]
# Basta somar cv2.THRESH_OTSU

# %%
metodo = cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU
ret, imgBin = cv2.threshold(img, 0, 255, metodo)

print("O melhor limiar é:", ret)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-19cb5f45ba66> in <cell line: 2>()
#       1 metodo = cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU
# ----> 2 ret, imgBin = cv2.threshold(img, 0, 255, metodo)
#       3
#       4 print("O melhor limiar é:", ret)
#
# error: OpenCV(4.7.0) /io/opencv/modules/imgproc/src/thresh.cpp:1555: error: (-2:Unspecified error) in function 'double cv::threshold(cv::InputArray, cv::OutputArray, double, double, int)'
# > THRESH_OTSU mode:
# >     'src_type == CV_8UC1 || src_type == CV_16UC1'
# > where
# >     'src_type' is 16 (CV_8UC3)

# %%
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img)
plt.title("Imagem Original")

ax2 = fig.add_subplot(222)
plt.imshow(imgBin)

plt.show()
