# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread('estrada.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(img, 70, 255)

# %% [markdown]
# Função HoughLinesP

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 10, 200)

# %% [markdown]
# Desenhar as linhas encontradas

# %%
for line in lines:
  x1, y1, x2, y2 = line[0]
  cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 3)

cv2_imshow(img)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=700x438 at 0x7F0C8330D490>
